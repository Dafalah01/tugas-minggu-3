# %%
#Tugas 1
#Input
biodata=["Muhammad Dafa Falah Labib","2420506048","Magelang","163","62"]
a,b,c,d,e = biodata
#Output
print('BIODATA MAHASISWA')
print('Nama         :',a)
print('NPM          :',b)
print('Alamat       :',c)
print('Tinggi Badan :',d)
print('Berat badan  :',e)
# Out:
# BIODATA MAHASISWA
# Nama         : Muhammad Dafa Falah Labib
# NPM          : 2420506048
# Alamat       : Magelang
# Tinggi Badan : 163
# Berat badan  : 62

# %%
#Tugas 2

print ("""\033[1mUNIVERSITAS TIDAR\033[0m
Universitas Tidar merupakan Perguruan Tinggi Pemerintahan atau Perguruan Tinggi negeri yang telah ditetapkan berdasarkan peraturan presiden republik indonesia nomor 32 tahun 2004 pada tanggal 1 april 2014

\033[1mJURUSAN TEKNIK ELEKTRO MEKATRONIKA DAN INFORMASI\033[0m
Jurusan teknik elektro mekatronika dan informasi terdiri atas tiga program studi antara lain:
   1. Teknik Elektro (\033[3mBachelor of Electrical Engineering\033[0m)
   2. Teknologi Informasi (\033[3mBachelor of Information Technologi\033[0m)
   3. Teknik Mekatronika (\033[3mBachelor of Mechatronics Engineering\033[0m)""")
# Out:
# UNIVERSITAS TIDAR
# Universitas Tidar merupakan Perguruan Tinggi Pemerintahan atau Perguruan Tinggi negeri yang telah ditetapkan berdasarkan peraturan presiden republik indonesia nomor 32 tahun 2004 pada tanggal 1 april 2014
#
# JURUSAN TEKNIK ELEKTRO MEKATRONIKA DAN INFORMASI
# Jurusan teknik elektro mekatronika dan informasi terdiri atas tiga program studi antara lain:
#    1. Teknik Elektro (Bachelor of Electrical Engineering)
#    2. Teknologi Informasi (Bachelor of Information Technologi)
#    3. Teknik Mekatronika (Bachelor of Mechatronics Engineering)
